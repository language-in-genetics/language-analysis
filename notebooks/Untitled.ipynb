# %%
# !pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from selenium import webdriver
#       2 from selenium.webdriver.chrome.service import Service
#       3 from selenium.webdriver.common.by import By
#
# ModuleNotFoundError: No module named 'selenium'

# %%
# Initialize Chrome WebDriver
driver = webdriver.Edge
try:
    # Open the target URL
    url = "https://onlinelibrary.wiley.com/loi/15733599"
    driver.get(url)
    
    # Optional: Wait for the page to load (modify as needed based on load time)
    time.sleep(3)
    
    # Get the page source
    page_source = driver.page_source
    print(page_source)  # Print or process the HTML source as needed

finally:
    # Close the browser
    driver.quit()

# %%
r = requests.get('https://onlinelibrary.wiley.com/loi/15733599')

# %%
r.status_code
# Out:
# 403
